# %%
import pandas as pd
import numpy as np
import re
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("alldata.csv")

# %%
data
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# ...

# %%
cols = []
for i in range(len(data.columns)):
    cols.append(data.columns[i].lower().replace(' ', '_'))
data.columns = cols
print(data.columns)
# Out:
# Index(['position', 'company', 'description', 'reviews', 'location'], dtype='object')

# %%
data.dtypes
# Out:
# position        object
# company         object
# description     object
# reviews        float64
# location        object
# dtype: object

# %%
data['reviews'] = data['reviews'].fillna(0)

# %%
data
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# ...

# %%
data = data.dropna(axis=0, how = 'any') #remove rows with all null values

# %%
newlocation = [str(row).rstrip() for row in data['location']]
newlocation = [re.sub('[\s*]+[\d]+[\d]+[\d]+[\d]+[\d]','',row) for row in newlocation]
data['newlocation'] = pd.Series(newlocation,index = data.index)
data['newlocation'].unique()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# array(['Atlanta, GA', 'Austin, TX', 'Round Rock, TX', 'Cedar Park, TX',
#        'Boulder, CO', 'Boston, MA', 'Chicago, IL', 'Washington, DC',
#        'Los Angeles, CA', 'Cambridge, MA', 'Mountain View, CA',
#        'Manhattan, NY', 'New York, NY', 'Jersey City, NJ', 'Newark, NJ',
#        'Oakland, NJ', 'Bronx, NY', 'Hoboken, NJ', 'Brooklyn, NY',
#        'Rutherford, NJ', 'Union, NJ', 'Rahway, NJ', 'Murray Hill, NJ',
#        'South Plainfield, NJ', 'Queens, NY', 'Little Falls, NJ',
# ...

# %%
data["location"] = data["newlocation"]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.drop(columns=["newlocation"])
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# ...

# %%
from collections import Counter
Counter(" ".join(data["position"]).split()).most_common(100)
# Out:
# [('Data', 2030),
#  ('Scientist', 2022),
#  ('-', 1287),
#  ('Research', 1064),
#  ('Senior', 988),
#  ('Engineer', 945),
#  ('Analyst', 713),
#  ('Learning', 520),
#  ('Software', 507),
#  ('Machine', 504),
#  ('Scientist,', 471),
#  ('Associate', 372),
#  ('Manager', 346),
#  ('and', 306),
#  ('Development', 305),
#  ('Sr.', 296),
#  ('&', 290),
#  ('/', 266),
#  ('Science', 230),
#  ('Principal', 225),
#  ('Analytics', 217),
#  ('Product', 211),
#  ('Lead', 191),
#  ('Engineer,', 182),
#  ('Manager,', 171),
#  ('of', 156),
#  ('Quantitative', 142),
#  ('Technical', 136),
#  ('I', 132),
#  ('Specialist', 131),
#  ('Director,', 130),
#  ('Engineering', 121),
#  ('Clinical', 121),
#  ('Developer', 118),
#  ('Business', 116),
#  ('Director', 112),
#  ('II', 112),
#  ('Operations', 109),
#  ('–', 108),
#  ('Staff', 107),
#  ('Program', 102),
#  ('Applied', 101),
#  ('Sr', 100),
#  ('Analyst,', 97),
#  ('Systems', 95),
#  ('Marketing', 92),
#  ('Security', 91),
#  ('Assistant', 88),
# ...

# %%
from collections import Counter
Counter(" ".join(data["description"]).split()).most_common(100)
# Out:
# [('and', 215669),
#  ('to', 108160),
#  ('of', 91354),
#  ('the', 89184),
#  ('in', 67251),
#  ('a', 60527),
#  ('with', 53032),
#  ('for', 39622),
#  ('or', 32922),
#  ('data', 29962),
#  ('is', 28034),
#  ('as', 20789),
#  ('on', 19161),
#  ('will', 18896),
#  ('our', 18225),
#  ('experience', 16897),
#  ('be', 15866),
#  ('are', 15598),
#  ('an', 15549),
#  ('that', 15293),
#  ('work', 14505),
#  ('team', 12469),
#  ('The', 11345),
#  ('We', 10814),
#  ('you', 10731),
#  ('Experience', 10717),
#  ('at', 10249),
#  ('other', 9509),
#  ('business', 9488),
#  ('research', 9368),
#  ('from', 8950),
#  ('by', 8935),
#  ('development', 8627),
#  ('have', 8347),
#  ('years', 7912),
#  ('we', 7800),
#  ('new', 7722),
#  ('including', 7363),
#  ('skills', 7355),
#  ('technical', 7010),
#  ('all', 6835),
#  ('You', 6730),
#  ('working', 6557),
#  ('your', 6486),
#  ('related', 6380),
#  ('support', 6093),
#  ('Data', 6084),
#  ('software', 5819),
#  ('learning', 5788),
# ...

# %%
data['description'].map(lambda x: True if 'bachelor' in str(x) else False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6959    False
# 6960    False
# 6961    False
# 6962    False
# 6963    False
# Name: description, Length: 6953, dtype: bool

# %%
lst = ["bachelor", "undergrad"]

if 
    data["description"].str.extractall(
    '({})'.format('|'.join(lst))
).groupby(level=0)[0].value_counts().unstack(fill_value=0) > 0:
# Out:
# 0     bachelor  undergrad
# 8            0          2
# 10           1          0
# 19           0          1
# 23           1          0
# 26           1          0
# ...        ...        ...
# 6270         1          0
# 6296         0          1
# 6328         0          1
# 6430         1          0
# 6527         0          1
#
# [204 rows x 2 columns]

# %%
data
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# ...

# %%
data["master"] = data['description'].map(lambda x: True if 'master' in str(x) else False)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data["high_school"] = data['description'].map(lambda x: True if 'high school' in str(x) else False)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data["phd"] = data['description'].map(lambda x: True if 'phd' in str(x) else False)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# ...

# %%
data.bachelor.value_counts()
# Out:
# False    6821
# True      132
# Name: bachelor, dtype: int64

# %%
data.master.value_counts()
# Out:
# False    6666
# True      287
# Name: master, dtype: int64

# %%
data.phd.value_counts()
# Out:
# False    6953
# Name: phd, dtype: int64

# %%
data[data["bachelor"]==True]["bachelor"].sum()
# Out:
# 0

# %%
data['company'].unique()
# Out:
# array(['ALS TDI', 'The Hexagon Lavish', 'Xpert Staffing', ..., 'Nexient',
#        'Arosys', 'Whiterabbit.ai'], dtype=object)

# %%
data['position'].unique()
# Out:
# array(['Development Director',
#        'An Ostentatiously-Excitable Principal Research Assistant to Chief Scientist',
#        'Data Scientist', ..., 'Data Developer / Machine Learning Analyst',
#        'Intern Scientist', 'Principal Data Scientist, Deep Learning'],
#       dtype=object)

# %%
lower_position = [position.lower() for position in data['position']]

# %%
category = []
for position in lower_position:
    if "data scientist" in position or 'data science' in position or "machine learning" in position:
        category.append('data scientist')
    elif "analyst" in position or "analytics" in position:
        category.append('analyst')
    elif "engineer" in position or "artificial intelligence" in position or "ai" in position:
        category.append('engineer')
    elif "software" in position or "python" in position or "java" in position or "developer" in position:
        category.append("software engineer")
    else:
        category.append('other')

# %%
data['title_category'] = category
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# ...
